# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cli_data = pd.read_csv("C:/Users/Ann/Desktop/DATA 3/climate_change.csv")
# cli_data.to_csv("C:/Users/Ann/Desktop/DATA 3/climate_change.csv")

# %%
cli_data.describe(include ='all')
# Out:
#           Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1              record_id  \
# count   29523.000000  29523.000000    29523.000000                  29523
# unique           NaN           NaN             NaN                  29523
# top              NaN           NaN             NaN  f1_fuel_1994_12_1_0_7
# freq             NaN           NaN             NaN                      1
# mean    14761.000000  14761.000000    14761.000000                    NaN
# std      8522.700335   8522.700335     8522.700335                    NaN
# min         0.000000      0.000000        0.000000                    NaN
# 25%      7380.500000   7380.500000     7380.500000                    NaN
# 50%     14761.000000  14761.000000    14761.000000                    NaN
# 75%     22141.500000  22141.500000    22141.500000                    NaN
# max     29522.000000  29522.000000    29522.000000                    NaN
#
#         utility_id_ferc1   report_year plant_name_ferc1 fuel_type_code_pudl  \
# ...

# %%
cli_data.isnull().sum()
# Out:
# Unnamed: 0                        0
# Unnamed: 0.1                      0
# Unnamed: 0.1.1                    0
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
